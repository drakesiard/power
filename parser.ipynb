# %%
import pandas as pd
import zipfile as zip

# %%
with zip.ZipFile('/tmp/mozilla_drake0/2020_Oct-Dec_RT_LMPs.zip') as zip_archive:
    with zip_archive.open('2020_Oct-Dec_RT_LMPs/2020_Oct-Dec_RT_LMPs.csv') as zip_file:
        df = pd.read_csv(zip_file)
# Out:
# /home/drake/.virtualenvs/power/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (11,12,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#         MARKET_DAY         NODE       TYPE VALUE    HE1    HE2    HE3    HE4  \
# 0        10/1/2020          AEC  Interface   LMP   9.41  11.14  11.18  10.47
# 1        10/1/2020          AEC  Interface   MCC   0.81   2.14   1.57   1.30
# 2        10/1/2020          AEC  Interface   MLC   0.13   0.07   0.06   0.07
# 3        10/1/2020         AECI  Interface   LMP   9.61  11.91  10.25   7.35
# 4        10/1/2020         AECI  Interface   MCC   1.74   3.54   1.29  -1.16
# ...            ...          ...        ...   ...    ...    ...    ...    ...
# 628084  12/31/2020  WR.THAYERLD   Loadzone   MCC   0.00   0.00   0.00   0.00
# 628085  12/31/2020  WR.THAYERLD   Loadzone   MLC   0.19   0.18   0.19   0.23
# 628086  12/31/2020          YAD  Interface   LMP  18.39  17.47  17.15  17.28
# 628087  12/31/2020          YAD  Interface   MCC   0.00   0.00   0.00   0.00
# 628088  12/31/2020          YAD  Interface   MLC  -0.16  -0.07   0.01   0.01
#
# ...

# %%
df.query('VALUE == "LMP"').describe()
# Out:
#                  HE1            HE2            HE3            HE4  \
# count  209363.000000  209363.000000  209363.000000  209363.000000
# mean       17.117901      16.060821      15.911834      16.043441
# std        12.484467      11.194830      12.089053      11.391300
# min      -502.970000    -508.900000    -410.410000    -533.190000
# 25%        14.580000      13.900000      13.730000      14.040000
# 50%        18.230000      17.770000      17.760000      17.780000
# 75%        21.160000      20.320000      20.200000      20.470000
# max       429.850000     319.200000     410.880000     277.840000
#
#                  HE5            HE6            HE7           HE10  \
# count  209363.000000  209363.000000  209363.000000  209363.000000
# mean       16.533306      17.895785      20.035562      23.164085
# std        11.351419      13.192709      13.040438      14.061819
# min      -544.860000    -452.000000    -531.790000    -565.770000
# ...
